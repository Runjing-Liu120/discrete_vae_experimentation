# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline  

import torch
import torch.nn as nn

import torch.optim as optim

from copy import deepcopy

from torch.distributions import Categorical, Normal

import itertools

import sys
sys.path.insert(0, './../libraries/')

import partial_marginalization_lib as pm_lib
import galaxy_experiments_lib as galaxy_lib

import sys
sys.path.insert(0, '../../../celeste_net/')
import celeste_net 

from celeste_net import OneGalaxyVAE


from datasets import Synthetic

# %%
# loss_array_top0 = np.load('../galaxy_results/topk0/galaxy_vae_topk0_batch_losses_array.npy')
loss_array_top0 = np.load('../galaxy_results_sandbox2/topk0/galaxy_vae_topk0_batch_losses_array.npy')
loss_array_top1 = np.load('../galaxy_results_sandbox2/topk1/galaxy_vae_topk1_batch_losses_array.npy')
loss_array_top3 = np.load('../galaxy_results_sandbox2/topk3/galaxy_vae_topk3_batch_losses_array.npy')
loss_array_top5 = np.load('../galaxy_results_sandbox2/topk5/galaxy_vae_topk5_batch_losses_array.npy')
loss_array_top10 = np.load('../galaxy_results_sandbox2/topk10/galaxy_vae_topk10_batch_losses_array.npy')

# %%
plt.semilogy(loss_array_top0[0::20], '--')
plt.semilogy(loss_array_top1[0::20], '--')
plt.semilogy(loss_array_top3[0::20], '--')
plt.semilogy(loss_array_top5[0::20], '--')
plt.semilogy(loss_array_top10[0::20], '--')


plt.xlabel('iteration')
plt.ylabel('loss')
plt.legend(('1', '3'))

# %%
plt.plot(loss_array_top0[50:], 'x--')
plt.plot(loss_array_top5[50:], 'x--')
plt.plot(loss_array_top10[50:], 'x--')
plt.plot(loss_array_top15[50:], 'x--')


plt.xlabel('iteration')
plt.ylabel('loss')
# Out:
# Text(0,0.5,'loss')

# %%
loss_array_top0 = np.load('../galaxy_results/topk0/galaxy_vae_topk0_test_losses_array.npy')
loss_array_top5 = np.load('../galaxy_results/topk5/galaxy_vae_topk5_test_losses_array.npy')

# %%
plt.semilogy(loss_array_top0, '--')
plt.semilogy(loss_array_top5, '--')

plt.xlabel('iteration')
plt.ylabel('loss')
plt.legend(('0', '5'))

# %%
loss_array_top5 = np.load('../galaxy_results_sandbox2/topk1/galaxy_vae_topk1_test_losses_array.npy')
loss_array_reinforce6 = np.load('../galaxy_results_sandbox2/reinforce2/galaxy_vae_reinforce2_test_losses_array.npy')

# %%
plt.semilogy(loss_array_top5[0::20], '--')
plt.semilogy(loss_array_reinforce6[0::20], '--')

plt.xlabel('iteration')
plt.ylabel('loss')
plt.legend(('top', 'reinforce'))
